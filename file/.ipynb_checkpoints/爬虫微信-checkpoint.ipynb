# %%
#!/usr/bin/python 
#coding: utf-8
 
import itchat,time
from itchat.content import TEXT
import importlib
importlib.reload(sys)
import sys

# %%
itchat.auto_login(enableCmdQR = False)
# Out:
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as Joe Vinson🌝

# %%
roomslist = itchat.get_chatrooms()
itchat.dump_login_status() # 显示所有的群聊信息，默认是返回保存到通讯录中的群聊
myroom=itchat.search_chatrooms(name=u'2018哥大统计录取群') #群聊名称
gsq=itchat.update_chatroom(myroom[0]['UserName'], detailedMember=True)

# %%
with open('2018哥大统计群数据.txt','a',encoding='utf-8') as f:
    for c in gsq['MemberList']:
        f.write(c['NickName'] + " " + c['DisplayName'] +" " + str(c['Sex']) +" "+ str(c['Province'])+ " "+str(c['City'])+'\n')

# %%
gsq['MemberList']
# Out:
# <ContactList: [<ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@9611b533eecebdfaa7771674f489e237', 'NickName': 'PARIS🍿', 'AttrStatus': 67227175, 'PYInitial': 'PARIS?', 'PYQuanPin': 'PARIS?', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '', 'KeyWord': 'par', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@9611b533eecebdfaa7771674f489e237&chatroomid=@a368e769ffec861987430f8edfb36290&skey=', 'ContactFlag': 0, 'MemberCount': 0, 'RemarkName': '', 'HideInputBarFlag': 0, 'Sex': 2, 'Signature': '等🐈族', 'VerifyFlag': 0, 'OwnerUin': 0, 'StarFriend': 0, 'AppAccountFlag': 0, 'Statues': 0, 'Province': '四川', 'City': '成都', 'Alias': '', 'SnsFlag': 177, 'UniFriend': 0, 'ChatRoomId': 0, 'EncryChatRoomId': '@a368e769ffec861987430f8edfb36290', 'IsOwner': 0}>, <ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@e214bdb5ef6437c4e703079ebea7bfde', 'NickName': '肖晶 Lois', 'AttrStatus': 67305765, 'PYInitial': 'XJLOIS', 'PYQuanPin': 'xiaojingLois', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': 'Lois UConn', 'KeyWord': 'a22', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@e214bdb5ef6437c4e703079ebea7bfde&chatroomid=@a368e769ffec861987430f8edfb36290&skey=', 'ContactFlag': 0, 'MemberCount': 0, 'RemarkName': '', 'HideInputBarFlag': 0, 'Sex': 2, 'Signature': '2019 好好学习 天天向上 ', 'VerifyFlag': 0, 'OwnerUin': 0, 'StarFriend': 0, 'AppAccountFlag': 0, 'Statues': 0, 'Province': '', 'City': '', 'Alias': '', 'SnsFlag': 177, 'UniFriend': 0, 'ChatRoomId': 0, 'EncryChatRoomId': '@a368e769ffec861987430f8edfb36290', 'IsOwner': 0}>, <ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@65a6212564ca6da24ecc19e74ac8aa06', 'NickName': '😜😜哼哼😜😜', 'AttrStatus': 4271807, 'PYInitial': 'SPANCLASSEMOJIEMOJI1F61CSPANSPANCLASSEMOJIEMOJI1F61CSPANHHSPANCLASSEMOJIEMOJI1F61CSPANSPANCLASSEMOJIEMOJI1F61CSPAN', 'PYQuanPin': 'spanclassemojiemoji1f61cspanspanclassemojiemoji1f61cspanhenghengspanclassemojiemoji1f61cspanspanclassemojiemoji1f61cspan', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '柏川-华大', 'KeyWord': 'zbc', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@65a6212564ca6da24ecc19e74ac8aa06&chatroomid=@a368e769ffec861987430f8edfb36290&skey=', 'ContactFlag': 0, 'MemberCount': 0, 'RemarkName': '', 'HideInputBarFlag': 0, 'Sex': 1, 'Signature': 'Men learn from history that men learnt nothing from history', 'VerifyFlag': 0, 'OwnerUin': 0, 'StarFriend': 0, 'AppAccountFlag': 0, 'Statues': 0, 'Province': '广东', 'City': '深圳', 'Alias': '', 'SnsFlag': 49, 'UniFriend': 0, 'ChatRoomId': 0, 'EncryChatRoomId': '@a368e769ffec861987430f8edfb36290', 'IsOwner': 0}>, <ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@28fe90cdb18bb23df6f430c9c8259061', 'NickName': '灰灰', 'AttrStatus': 112741, 'PYInitial': 'HH', 'PYQuanPin': 'huihui', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '杨朝晖 uconn', 'KeyWord': 'yan', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@28fe90cdb18bb23df6f430c9c8259061&chatroomid=@a368e769ffec861987430f8edfb36290&skey=', 'ContactFlag': 0, 'MemberCount': 0, 'RemarkName': '', 'HideInputBarFlag': 0, 'Sex': 1, 'Signature': '', 'VerifyFlag': 0, 'OwnerUin': 0, 'StarFriend': 0, 'AppAccountFlag': 0, 'Statues': 0, 'Province': '上海', 'City': '长宁', 'Alias': '', 'SnsFlag': 177, 'UniFriend': 0, 'ChatRoomId': 0, 'EncryChatRoomId': '@a368e769ffec861987430f8edfb36290', 'IsOwner': 0}>, <ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@617db12b6db383a71b9dced004d3eee0a7e10052affac4f7bcd2fe0faf78dba5', 'NickName': '酥梨', 'AttrStatus': 102439, 'PYInitial': 'SL', 'PYQuanPin': 'suli', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '程瑜佳(Suli)-econ➕stats-UConn', 'KeyWord': '', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@617db12b6db383a71b9dced ...

# %%
froomslist = itchat.get_chatrooms()
itchat.dump_login_status() # 显示所有的群聊信息，默认是返回保存到通讯录中的群聊
myroom=itchat.search_chatrooms(name=u'哥大统计美国zhiye群') #群聊名称
gsq=itchat.update_chatroom(myroom[0]['UserName'], detailedMember=True)
# Out:
# 男生好友比例 : 40.33%
# 女生好友比例 : 51.81%

# %%
with open('2018哥大统计群数据.txt','a',encoding='utf-8') as f:
    for c in gsq['MemberList']:
        f.write(c['NickName'] + " " + c['DisplayName'] +" " + str(c['Sex']) +" "+ str(c['Province'])+ " "+str(c['City'])+'\n')
